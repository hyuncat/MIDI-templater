# %% [markdown]
# # DTW: Part II
#
# Only allowing 1-to-1 matches! CQT with onset annotations!!

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../..')
from app.config import AppConfig

from app.modules.audio.AudioData import AudioData
from app.modules.audio.AudioPlayer import AudioPlayer
from app.modules.midi.MidiData import MidiData
from app.modules.midi.MidiPlayer import MidiPlayer
from app.modules.midi.MidiSynth import MidiSynth

from archive.PitchAnalyzer import PitchAnalyzer
from app.modules.dtw.MidiDTW import MidiDTW, CQTFeatures
from app.modules.dtw.PitchDTW import PitchDTW
# Out:
# Importing the dtw module. When using in academic works please cite:
#   T. Giorgino. Computing and Visualizing Dynamic Time Warping Alignments in R: The dtw Package.
#   J. Stat. Soft., doi:10.18637/jss.v031.i07.

# %% [markdown]
# ### Step 0: Listen to the query (MIDI) vs. the template (ME)
#
# Our goal is to warp the MIDI note lengths to match the user's recorded audio note lengths so we can easily compare pitches just by jumping to a point in the midifile.

# %%
# Create a synth with a soundfont
SOUNDFONT_FILEPATH = '../../app/resources/MuseScore_General.sf3'
midi_synth = MidiSynth(SOUNDFONT_FILEPATH)

# Load the midi file into a MidiData object
MIDI_FILEPATH = '../../app/resources/midi/fugue.mid'
midi_data = MidiData(MIDI_FILEPATH)

# Create MidiSynth/Player objects
midi_player = MidiPlayer(midi_synth)
midi_player.load_midi(midi_data)
# Out:
# Loading MidiSynth...
# Synth + soundfont loaded.

# %%
AUDIO_FILEPATH = '../../app/resources/audio/user_fugue2.mp3'

audio_data = AudioData()
audio_data.load_data(AUDIO_FILEPATH)
audio_player = AudioPlayer()
audio_player.load_audio_data(audio_data)

# %%
# Playback either the MIDI or user audio

# midi_player.play(start_time=0)
# audio_player.play(start_time=0)

# %% [markdown]
# ## Step 1: Compute CQTs
#
# CQT, or Constant-Q transform, represents the amount of energy in logarithmically spaced bins
#
# Raffel, Ellis 2016 uses a constant-Q spectra spanning 4 octaves starting from MIDI note C2 (65.4 Hz) with 12 bins / octave. We also compute the log-amplitude and normalize the CQT for better results.

# %% [markdown]
# ## Step 2: Compute onsets
#
# MIDI onsets are determined by the file.
#
# Within user audio, we detect two kinds of onsets
# - `pitch_diff` - Using rolling median to detect when the pitch significantly changes
# - `onset` - From essentia's 'complex' onset detection algorithm
#
# Maybe instead of only getting the frame of CQT at the given onset, we get the mean/median of the nearest 10 frames? (Still a very small fraction of a second)

# %%
import numpy as np
import pandas as pd

MIDI_FILEPATH = '../../app/resources/midi/fugue.mid'

midi_audio = AudioData()
midi_audio.load_midi_file(MIDI_FILEPATH, SOUNDFONT_FILEPATH)
midi_data = MidiData(MIDI_FILEPATH)

midi_features = PitchDTW.midi_features(midi_data, midi_audio)

midi_features.onset_df
# Out:
# /Users/sarah/Desktop/shasha/MIDI-templater/notebooks/dtw/../../app/modules/dtw/PitchDTW.py:87: ComplexWarning: Casting complex values to real discards the imaginary part
#   cqt = cqt.astype(np.float32) # Store CQT as float32 to save space/memory
#          time                                           cqt_norm
# 0    0.000000  [-0.14525023, -0.18123695, -0.11763161, -0.101...
# 1    0.187500  [-0.14852832, -0.17480467, -0.22856793, -0.165...
# 2    0.375001  [-0.143507, -0.13530675, -0.13743159, -0.16570...
# 3    0.562501  [-0.15402356, -0.15334125, -0.14288092, -0.175...
# 4    0.750002  [-0.13072205, -0.13550499, -0.13812448, -0.149...
# ..        ...                                                ...
# 60  11.250030  [-0.16708627, -0.16488738, -0.18230057, -0.191...
# 61  11.437530  [-0.14122336, -0.20475908, -0.17110944, -0.152...
# 62  11.625031  [-0.16504312, -0.16297162, -0.15491305, -0.178...
# 63  11.812532  [-0.1611859, -0.14830263, -0.137423, -0.126110...
# 64  12.000032  [-0.15323158, -0.14991778, -0.1520378, -0.1347...
#
# [65 rows x 2 columns]

# %%
user_features = PitchDTW.user_features(audio_data)
user_features.resegment_notes(15, .4)
user_features.onset_df
# Out:
# /Users/sarah/Desktop/shasha/MIDI-templater/notebooks/dtw/../../app/modules/dtw/PitchDTW.py:87: ComplexWarning: Casting complex values to real discards the imaginary part
#   cqt = cqt.astype(np.float32) # Store CQT as float32 to save space/memory
# Computing pitches...
# Done! Took 0.82 seconds.
# Segmenting notes with window_size=15 and threshold=0.5...
# Detecting onsets...
# Onset detection complete.
# Segmenting notes with window_size=15 and threshold=0.4...
#           time  pitch_diff  onset  \
# 0     0.000000        True  False
# 1     0.011610       False   True
# 2     0.232200       False   True
# 3     0.281542        True  False
# 4     0.464399       False   True
# ..         ...         ...    ...
# 111  12.399456       False   True
# 112  12.707120        True  False
# 113  12.759365       False   True
# 114  12.910295       False   True
# 115  13.026395       False   True
#
#                                               cqt_norm
# 0    [-0.14135821, -0.13323016, -0.13167313, -0.127...
# 1    [-0.14135821, -0.13323016, -0.13167313, -0.127...
# 2    [-0.17201978, -0.20225146, -0.17587388, -0.155...
# 3    [-0.16227724, -0.16676936, -0.19005923, -0.189...
# 4    [-0.1720972, -0.18694374, -0.1710854, -0.19140...
# ..                                                 ...
# 111  [-0.1905904, -0.20403548, -0.23165557, -0.1904...
# 112  [-0.15978037, -0.15970814, -0.1913471, -0.1776...
# 113  [-0.16436683, -0.2036859, -0.21692996, -0.2131...
# 114  [-0.20493986, -0.19791424, -0.1963422, -0.1954...
# 115  [-0.17556979, -0.16978648, -0.18640739, -0.223...
#
# [116 rows x 4 columns]

# %% [markdown]
# ## Step 3: Align the two sequences
# Uses the cosine similarities of CQT vectors as a distance metric between MIDI/user onsets.

# %%
alignment = PitchDTW.align(user_features, midi_features)
# Out:
# DTW alignment computed.
# Distance: 4.988934405448402
# Mean alignment error: 25.896551724137932

# %%
# Plot the alignment path
alignment.plot()
# Out:
# <Axes: xlabel='Query index', ylabel='Reference index'>

# %% [markdown]
# ## Evaluate: Listen back
# Export the aligned MIDI to file and playback. Results are pretty accurate.

# %%
PitchDTW.export_midi(alignment, user_features, 
                     midi_features, midi_data)
# Out:
# Aligned MIDI written to aligned.mid

# %%
# Initialize a MidiSynth + MidiPlayer with a given soundfont
midi_synth = MidiSynth(soundfont_path=SOUNDFONT_FILEPATH)
midi_player = MidiPlayer(midi_synth)

# Play a given midi file
MIDI_FILEPATH = 'aligned.mid'
midi_player.load_midi(MIDI_FILEPATH)
midi_player.play(start_time=0)
# Out:
# Loading MidiSynth...
# Synth + soundfont loaded.

# %%
aligned_audio = AudioData()
aligned_audio.load_midi_file('aligned.mid', SOUNDFONT_FILEPATH)

from scipy.io.wavfile import write
write('output_audio.wav', 44100, aligned_audio.data)

# %%
PitchDTW.print_aligned_times(alignment, user_features, midi_features)
# Out:
# Aligned times:
# Note 0: User time = 0.00, MIDI time = 0.00
# Note 1: User time = 0.01, MIDI time = 0.00
# Note 2: User time = 0.02, MIDI time = 0.19
# Note 3: User time = 0.23, MIDI time = 0.19
# Note 4: User time = 0.42, MIDI time = 0.19
# Note 5: User time = 0.44, MIDI time = 0.38
# Note 6: User time = 0.46, MIDI time = 0.38
# Note 7: User time = 0.51, MIDI time = 0.38
# Note 8: User time = 0.64, MIDI time = 0.56
# Note 9: User time = 0.66, MIDI time = 0.56
# Note 10: User time = 0.74, MIDI time = 0.56
# Note 11: User time = 0.79, MIDI time = 0.75
# Note 12: User time = 0.85, MIDI time = 0.75
# Note 13: User time = 0.89, MIDI time = 0.75
# Note 14: User time = 0.92, MIDI time = 0.94
# Note 15: User time = 1.09, MIDI time = 0.94
# Note 16: User time = 1.11, MIDI time = 0.94
# Note 17: User time = 1.15, MIDI time = 0.94
# Note 18: User time = 1.18, MIDI time = 1.13
# Note 19: User time = 1.27, MIDI time = 1.31
# Note 20: User time = 1.30, MIDI time = 1.31
# Note 21: User time = 1.36, MIDI time = 1.31
# Note 22: User time = 1.49, MIDI time = 1.31
# Note 23: User time = 1.67, MIDI time = 1.50
# Note 24: User time = 1.72, MIDI time = 1.50
# Note 25: User time = 1.93, MIDI time = 1.69
# Note 26: User time = 1.98, MIDI time = 1.69
# Note 27: User time = 2.09, MIDI time = 1.69
# Note 28: User time = 2.13, MIDI time = 1.88
# Note 29: User time = 2.30, MIDI time = 2.06
# Note 30: User time = 2.31, MIDI time = 2.06
# Note 31: User time = 2.33, MIDI time = 2.06
# Note 32: User time = 2.50, MIDI time = 2.25
# Note 33: User time = 2.52, MIDI time = 2.44
# Note 34: User time = 2.69, MIDI time = 2.44
# Note 35: User time = 2.73, MIDI time = 2.44
# Note 36: User time = 2.88, MIDI time = 2.63
# Note 37: User time = 2.92, MIDI time = 2.81
# Note 38: User time = 2.95, MIDI time = 2.81
# Note 39: User time = 3.10, MIDI time = 2.81
# Note 40: User time = 3.27, MIDI time = 3.00
# Note 41: User time = 3.46, MIDI time = 3.19
# Note 42: User time = 3.56, MIDI time = 3.19
# Note 43: User time = 3.60, MIDI time = 3.38
# Note 44: User time = 3.70, MIDI time = 3.56
# Note 45: User time = 3.74, MIDI time = 3.56
# Note 46: User time = 3.91, MIDI time = 3.56
# Note 47: User time = 3.95, MIDI time = 3.56
# Note 48: User time = 3.99, MIDI time = 3.56
# Note 49: User time = 4.12, MIDI time = 3.75
# Note 50: User time = 4.26, MIDI time = 3.94
# Note 51: User time = 4.32, MIDI time = 3.94
# Note 52: User time = 4.34, MIDI time = 3.94
# Note 53: User time = 4.40, MIDI time = 4.13
# Note 54: User time = 4.48, MIDI time = 4.31
# Note 55: User time = 4.54, MIDI time = 4.31
# Note 56: User time = 4.64, MIDI time = 4.31
# Note 57: User time = 4.70, MIDI time = 4.50
# Note 58: User time = 4.75, MIDI time = 4.50
# Note 59: User time = 4.91, MIDI time = 4.50
# Note 60: User time = 4.92, MIDI time = 4.50
# Note 61: User time = 5.09, MIDI time = 4.50
# Note 62: User time = 5.13, MIDI time = 4.69
# Note 63: User time = 5.27, MIDI time = 4.88
# Note 64: User time = 5.33, MIDI time = 5.06
# Note 65: User time = 5.35, MIDI time = 5.06
# Note 66: User time = 5.50, MIDI time = 5.25
# Note 67: User time = 5.53, MIDI time = 5.25
# Note 68: User time = 5.70, MIDI time = 5.44
# Note 69: User time = 5.71, MIDI time = 5.44
# Note 70: User time = 5.85, MIDI time = 5.44
# Note 71: User time = 5.92, MIDI time = 5.63
# Note 72: User time = 6.09, MIDI time = 5.81
# Note 73: User time = 6.11, MIDI time = 5.81
# Note 74: User time = 6.23, MIDI time = 5.81
# Note 75: User time = 6.30, MIDI time = 6.00
# Note 76: User time = 6.47, MIDI time = 6.19
# Note 77: User time = 6.52, MIDI time = 6.19
# Note 78: User time = 6.54, MIDI time = 6.19
# Note 79: User time = 6.59, MIDI time = 6.19
# Note 80: User time = 6.74, MIDI time = 6.38
# Note 81: User time = 6.91, MIDI time = 6.38
# Note 82: User time = 7.06, MIDI time = 6.56
# Note 83: User time = 7.12, MIDI time = 6.56
# Note 84: User time = 7.29, MIDI time = 6.75
# Note 85: User time = 7.53, MIDI time = 6.94
# Note 86: User time = 7.70, MIDI time = 7.13
# Note 87: User time = 7.71, MIDI time = 7.13
# Note 88: User time = 7.74, MIDI time = 7.13
# Note 89: User time = 7.78, MIDI time = 7.31
# Note 90: User time = 7.87, MIDI time = 7.31
# Note 91: User time = 7.90, MIDI time = 7.50
# Note 92: User time = 8.05, MIDI time = 7.50
# Note 93: User time = 8.11, MIDI time = 7.69
# Note 94: User time = 8.36, MIDI time = 7.69
# Note 95: User time = 8.45, MIDI time = 7.88
# Note 96: User time = 8.51, MIDI time = 8.06
# Note 97: User time = 8.56, MIDI time = 8.06
# Note 98: User time = 8.72, MIDI time = 8.25
# Note 99: User time = 8.74, MIDI time = 8.25
# Note 100: User time = 8.79, MIDI time = 8.25
# Note 101: User time = 8.89, MIDI time = 8.25
# Note 102: User time = 8.93, MIDI time = 8.25
# Note 103: User time = 9.10, MIDI time = 8.44
# Note 104: User time = 9.18, MIDI time = 8.63
# Note 105: User time = 9.32, MIDI time = 8.63
# Note 106: User time = 9.47, MIDI time = 8.63
# Note 107: User time = 9.52, MIDI time = 8.81
# Note 108: User time = 9.76, MIDI time = 9.00
# Note 109: User time = 9.88, MIDI time = 9.19
# Note 110: User time = 10.05, MIDI time = 9.38
# Note 111: User time = 10.21, MIDI time = 9.38
# Note 112: User time = 10.41, MIDI time = 9.56
# Note 113: User time = 10.43, MIDI time = 9.56
# Note 114: User time = 10.61, MIDI time = 9.75
# Note 115: User time = 10.81, MIDI time = 9.94
# Note 116: User time = 11.03, MIDI time = 10.13
# Note 117: User time = 11.19, MIDI time = 10.31
# Note 118: User time = 11.38, MIDI time = 10.50
# Note 119: User time = 11.40, MIDI time = 10.69
# Note 120: User time = 11.62, MIDI time = 10.88
# Note 121: User time = 11.75, MIDI time = 11.06
# Note 122: User time = 11.81, MIDI time = 11.06
# Note 123: User time = 11.85, MIDI time = 11.06
# Note 124: User time = 11.91, MIDI time = 11.06
# Note 125: User time = 11.94, MIDI time = 11.06
# Note 126: User time = 11.95, MIDI time = 11.06
# Note 127: User time = 12.02, MIDI time = 11.25
# Note 128: User time = 12.16, MIDI time = 11.25
# Note 129: User time = 12.19, MIDI time = 11.44
# Note 130: User time = 12.41, MIDI time = 11.63
# Note 131: User time = 12.51, MIDI time = 11.63
# Note 132: User time = 12.59, MIDI time = 11.63
# Note 133: User time = 12.65, MIDI time = 11.63
# Note 134: User time = 12.76, MIDI time = 11.63
# Note 135: User time = 12.77, MIDI time = 11.63
# Note 136: User time = 12.91, MIDI time = 11.63
# Note 137: User time = 13.03, MIDI time = 11.63
# Note 138: User time = 13.04, MIDI time = 11.63
# Note 139: User time = 13.06, MIDI time = 11.63
# Note 140: User time = 13.17, MIDI time = 11.63
# Note 141: User time = 13.26, MIDI time = 11.81
# Note 142: User time = 13.33, MIDI time = 11.81
# Note 143: User time = 13.34, MIDI time = 12.00

# %%
align_df = PitchDTW.align_df(alignment, user_features, midi_features)
align_df
# Out:
#     midi_time            user_times     user_midi_pitches
# 0    0.000000                 [0.0]  [62.053584300857395]
# 1    0.187500  [0.2321995496749878]  [62.125343629915264]
# 2    0.375001  [0.4643990993499756]  [61.060414026345136]
# 3    0.562501  [0.5427664399092971]   [61.05071368975765]
# 4    0.750002  [0.8736507936507937]   [76.50017929515381]
# ..        ...                   ...                   ...
# 60  11.250030  [12.144036293029785]   [63.25133191015265]
# 61  11.437530  [12.399456024169922]   [74.22629373385826]
# 62  11.625031  [12.707120181405896]   [73.22157253511757]
# 63  11.812532   [12.75936508178711]   [72.12890524398287]
# 64  12.000032  [12.910294532775879]   [72.10776645332764]
#
# [65 rows x 3 columns]

# %%
aligned_user = user_features.onset_df.iloc[alignment.index2].reset_index(drop=True)
aligned_midi = midi_features.onset_df.iloc[alignment.index1].reset_index(drop=True)

flat_align_df = pd.DataFrame({
    'midi_time': aligned_midi['time'],
    'user_time': aligned_user['time']
})

# Group user_times by midi_time
grouped = flat_align_df.groupby('midi_time')['user_time'].apply(list).reset_index()

# Create a new DataFrame with distinct MIDI times and corresponding user times
align_df = pd.DataFrame({
    'midi_time': grouped['midi_time'],
    'user_times': grouped['user_time'].apply(lambda x: x if len(x) > 0 else [None])
})

align_df
# Out:
#     midi_time                                         user_times
# 0    0.000000                         [0.0, 0.01160997711122036]
# 1    0.187500  [0.023217481467087304, 0.2321995496749878, 0.4...
# 2    0.375001  [0.435327777507887, 0.4614474441583602, 0.5136...
# 3    0.562501  [0.635578555161515, 0.6617687344551086, 0.7400...
# 4    0.750002  [0.7864921846975824, 0.8532424439154584, 0.893...
# ..        ...                                                ...
# 60  11.250030           [12.017948844401065, 12.155646324157715]
# 61  11.437530                               [12.189177770220835]
# 62  11.625031  [12.411066055297852, 12.508418140393285, 12.58...
# 63  11.812532           [13.260084102890238, 13.326834362108112]
# 64  12.000032                               [13.344247473208428]
#
# [65 rows x 2 columns]
