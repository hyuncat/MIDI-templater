# %%
from music21 import *
import pandas as pd


# Parse the violin part from the MIDI file
def parse_instrument(midi_stream, desired_instrument):
    """
    Get a desired instrument part from a MIDI file.
    @param:
        - midi_stream: music21.stream.Score object, the MIDI file to parse
        - desired_instrument: Type of the desired instrument part to return (e.g., instrument.Piano)
    @return:
        - The part of the desired instrument if found, otherwise None
    """
    for part in midi_stream.parts:
        for elem in part.recurse():
            if isinstance(elem, desired_instrument):
                return part
    return None


def make_instrument_df(instrument_part):
    """
    Create a DataFrame from a music21 stream of an instrument part.
    @param:
        - instrument_part: music21.stream.Part object, the instrument part to convert
    @return:
        - A pd.DataFrame with columns for pitch, MIDI number, frequency, duration, 
          and start time (aka 'offset', the # quarter notes from the beginning of piece)
          
    """
    instrument_flat = instrument_part.flatten()

    rows = []
    for element in instrument_flat.notes:
        if isinstance(element, note.Note):
            row = [
                element.pitch, 
                element.pitch.midi, 
                element.pitch.frequency,
                element.duration.quarterLength, 
                element.offset]
            # print(f'row: {row}')
        elif isinstance(element, chord.Chord):
            chord_pitches = ', '.join(str(p) for p in element.pitches)
            midi_pitches = ', '.join(str(p.midi) for p in element.pitches)
            frequencies = ', '.join(str(p.frequency) for p in element.pitches)
            row = [
                chord_pitches, 
                midi_pitches, 
                frequencies,
                element.duration.quarterLength, 
                element.offset]
            # print(f'row: {row}')
        rows.append(row)

    instrument_df = pd.DataFrame(rows, columns=['pitch', 'midi', 'frequency', 'duration', 'start'])
    return instrument_df


# Load the MIDI file using music21
music21_midi = converter.parse('../resources/midifiles/mozart_vc4_mvt1.mid')
violin_part = parse_instrument(music21_midi, instrument.Violin)
violin21_df = make_instrument_df(violin_part)

# Inspect the created df
violin21_df
# Out:
#         pitch    midi                              frequency duration    start
# 0          E6      88                            1318.510228     0.25    168.0
# 1          D6      86                            1174.659072     0.75   168.25
# 2          D6      86                            1174.659072     0.75    169.0
# 3          D6      86                            1174.659072     0.25   169.75
# 4          D6      86                            1174.659072      1.0    170.0
# ...       ...     ...                                    ...      ...      ...
# 2155  E6, F#6  88, 90  1318.5102276514808, 1479.977690846539     0.25   1067.0
# 2156  E6, F#6  88, 90  1318.5102276514808, 1479.977690846539     0.25  1067.25
# 2157   D6, G5  86, 79    1174.659071669631, 783.990871963499      0.5   1067.5
# 2158       E6      88                            1318.510228     0.25  1067.75
# 2159  F#5, D6  78, 86    739.988845423269, 1174.659071669631      1.5   1068.0
#
# [2160 rows x 5 columns]

# %%
import mido
import rtmidi
from mido import Message
import fluidsynth

class MidiSynthesizer:
    def __init__(self, soundfont_path):
        self.synth = fluidsynth.Synth()
        # Start the synthesizer with the appropriate audio driver
        self.synth.start(driver="coreaudio")  # Change to 'alsa', 'dsound', etc., based on your OS
        self.sf_id = self.load_soundfont(soundfont_path)
    
    def load_soundfont(self, soundfont_path):
        sf_id = self.synth.sfload(soundfont_path)
        if sf_id == -1:
            raise ValueError("Soundfont failed to load")
        return sf_id

    def program_select(self, channel, bank, preset):
        """
        Select the instrument program for a specific channel.

        @param:
            channel (int): MIDI channel (0-15)
            bank (int): SoundFont bank number
            preset (int): Preset number (program number) within the bank
        """
        self.synth.program_select(channel, self.sf_id, bank, preset)

    def play_note(self, channel, midi_number, velocity):
        """
        Play a note on a specific channel with given parameters.

        @param:
            - channel (int): MIDI channel on which to play the note
            - midi_number (int): MIDI number of the note to play
            - velocity (int): Velocity of the note (controls volume and articulation)
        """
        self.synth.noteon(channel, midi_number, velocity)

    def stop_note(self, channel, midi_number):
        """
        Stop a note on a specific channel.

        @param:
            - channel (int): MIDI channel on which to stop the note
            - midi_number (int): MIDI number of the note to stop
        """
        self.synth.noteoff(channel, midi_number)

    def stop(self):
        """
        Stop the synthesizer and clean up resources.
        """
        self.synth.delete()

    def handle_midi_message(self, msg: Message):
        """Handle different types of MIDI messages."""
        if msg.type == 'note_on':
            self.play_note(msg.channel, msg.note, msg.velocity)
        elif msg.type == 'note_off':
            self.stop_note(msg.channel, msg.note)
        elif msg.type == 'program_change':
            self.program_select(msg.channel, 0, msg.program)

# %%
midi_path = '../resources/midifiles/mozart_vc4_mvt1.mid'
soundfont_path = '../resources/soundfonts/MuseScore_General.sf3'

synth = MidiSynthesizer(soundfont_path)

# Function to play MIDI file
def play_midi_file(midi_file, synthesizer):
    midi_data = mido.MidiFile(midi_file)
    for msg in midi_data.play():
        if not msg.is_meta:
            print(dir(msg))
            synthesizer.handle_midi_message(msg)

# Example usage
# play_midi_file(midi_path, synth)

# %%
def create_msg_dict(midi_file):
    """
    Create dictionaries storing all messages and program controls for 
    the MIDI, assuming program is tied to the same channel throughout the piece
    @param:
        - midi_file: str, path to the MIDI file
    @return:
        - message_dict: dict, keys are elapsed time (in sec) and values are 
                        lists of messages all occuring at that time
            -> dict, {elapsed_time: [msg1, msg2, ...]}
        - program_dict: dict, with keys as channel number and values 
                        are a message of type 'program change'
            -> {channel: program_msg}
    """
    midi_data = mido.MidiFile(midi_file)
    message_dict = {}
    program_dict = {}  # Initialize program_dict
    elapsed_time = 0
    for msg in midi_data:
        if not msg.is_meta:
            elapsed_time += msg.time
            if elapsed_time not in message_dict:
                message_dict[elapsed_time] = []
            message_dict[elapsed_time].append(msg)

            # Check if the message is a 'program_change' message
            if msg.type == 'program_change':
                program_dict[msg.channel] = msg
    return message_dict, program_dict

midi_path = '../resources/midifiles/mozart_vc4_mvt1.mid'
message_dict, program_dict = create_msg_dict(midi_path)

# %%
message_dict
# Out:
# {0: [Message('control_change', channel=0, control=0, value=0, time=0),
#   Message('program_change', channel=0, program=40, time=0),
#   Message('control_change', channel=0, control=10, value=67, time=0),
#   Message('control_change', channel=0, control=91, value=66, time=0),
#   Message('control_change', channel=0, control=93, value=32, time=0),
#   Message('control_change', channel=0, control=121, value=0, time=0),
#   Message('control_change', channel=1, control=0, value=0, time=0),
#   Message('program_change', channel=1, program=48, time=0),
#   Message('control_change', channel=1, control=10, value=45, time=0),
#   Message('control_change', channel=1, control=91, value=66, time=0),
#   Message('control_change', channel=1, control=93, value=2, time=0),
#   Message('control_change', channel=1, control=121, value=0, time=0),
#   Message('control_change', channel=2, control=0, value=0, time=0),
#   Message('program_change', channel=2, program=48, time=0),
#   Message('control_change', channel=2, control=10, value=84, time=0),
#   Message('control_change', channel=2, control=91, value=63, time=0),
#   Message('control_change', channel=2, control=93, value=5, time=0),
#   Message('control_change', channel=2, control=121, value=0, time=0)],
#  0.19261839322916666: [Message('control_change', channel=0, control=10, value=63, time=0.19261839322916666),
#   Message('control_change', channel=1, control=10, value=53, time=0),
#   Message('control_change', channel=2, control=10, value=73, time=0)],
#  0.25727351822916666: [Message('control_change', channel=0, control=91, value=73, time=0.064655125),
#   Message('control_change', channel=1, control=91, value=73, time=0),
#   Message('control_change', channel=2, control=91, value=73, time=0)],
#  0.32192864322916664: [Message('control_change', channel=0, control=93, value=35, time=0.064655125)],
#  0.3865837682291666: [Message('program_change', channel=0, program=40, time=0.064655125),
#   Message('program_change', channel=1, program=48, time=0),
#   Message('program_change', channel=2, program=48, time=0)],
#  0.44046303906249995: [Message('control_change', channel=0, control=1, value=55, time=0.05387927083333333)],
#  2.067617018229167: [Message('note_on', channel=1, note=62, velocity=96, time=1.6271539791666667),
#   Message('note_on', channel=2, note=50, velocity=93, time=0),
#   Message('note_on', channel=2, note=38, velocity=93, time=0)],
#  2.5740821640625002: [Message('note_off', channel=1, note=62, velocity=0, time=0.5064651458333334),
#   Message('note_off', channel=2, note=50, velocity=0, time=0),
#   Message('note_off', channel=2, note=38, velocity=0, time=0)],
#  2.5848580182291667: [Message('note_on', channel=1, note=62, velocity=96, time=0.010775854166666666),
#   Message('note_on', channel=2, note=50, velocity=93, time=0),
#   Message('note_on', channel=2, note=38, velocity=93, time=0)],
#  2.9620129140625: [Message('note_off', channel=1, note=62, velocity=0, time=0.37715489583333334),
#   Message('note_off', channel=2, note=50, velocity=0, time=0),
#   Message('note_off', channel=2, note=38, velocity=0, time=0)],
#  2.9727887682291665: [Message('note_on', channel=1, note=62, velocity=108, time=0.010775854166666666),
#   Message('note_on', channel=2, note=50, velocity=93, time=0),
#   Message('note_on', channel=2, note=38, velocity=93, time=0)],
#  3.0913231640624996: [Message('note_off', channel=1, note=62, velocity=0, time=0.11853439583333333),
#   Message('note_off', channel=2, note=50, velocity=0, time=0),
#   Message('note_off', channel=2, note=38, velocity=0, time=0)],
#  3.102099018229166: [Message('note_on', channel=1, note=62, velocity=96, time=0.010775854166666666),
#   Message('note_on', channel=2, note=50, velocity=93, time=0),
#   Message('note_on', channel=2, note=38, velocity=93, time=0)],
#  3.6085641640624995: [Message('note_off', channel=1, note=62, velocity=0, time=0.5064651458333334),
#   Message('note_off', channel=2, note=50, velocity=0, time=0),
#   Message('note_off', channel=2, note=38, velocity=0, time=0)],
#  3.619340018229166: [Message('note_on', channel=1, note=62, velocity=96, time=0.010775854166666666),
#   Message('note_on', channel=2, note=50, velocity=93, time=0),
#   Message('note_on', channel=2, note=38, velocity=93, time=0)],
#  4.125805164062499: [Message('note_off', channel=1, note=62, velocity=0, time=0.5064651458333334),
#   Message('note_off', channel=2, note=50, velocity=0, time=0),
#   Message('note_off', channel=2, note=38, velocity=0, time=0)],
#  4.136581018229166: [Message('note_on', channel=1, note=62, velocity=96, time=0.010775854166666666),
#   Message('note_on', channel=2, note=50, velocity=93, time=0),
#   Message('note_on', channel=2, note=38, velocity=93, time=0)],
#  4.6430461640625: [Message('note_off', channel=1, note=62, velocity=0, time=0.5064651458333334),
#   Message('note_off', channel=2, note=50, velocity=0, time=0),
#   Message('note_off', channel=2, note=38, velocity=0, time=0)],
#  4.912442518229167: [Message('note_on', channel=1, note=66, velocity=96, time=0.26939635416666663),
#   Message('note_on', channel=2, note=54, velocity=93, time=0),
#   Message('note_on', channel=2, note=42, velocity=93, time=0)],
#  5.036364841145834: [Message('note_off', channel=1, note=66, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=2, note=54, velocity=0, time=0),
#   Message('note_off', channel=2, note=42, velocity=0, time=0)],
#  5.171063018229167: [Message('note_on', channel=1, note=69, velocity=96, time=0.13469817708333331),
#   Message('note_on', channel=2, note=57, velocity=93, time=0),
#   Message('note_on', channel=2, note=45, velocity=93, time=0)],
#  5.6775281640625: [Message('note_off', channel=1, note=69, velocity=0, time=0.5064651458333334),
#   Message('note_off', channel=2, note=57, velocity=0, time=0),
#   Message('note_off', channel=2, note=45, velocity=0, time=0)],
#  5.946924518229167: [Message('note_on', channel=1, note=66, velocity=96, time=0.26939635416666663),
#   Message('note_on', channel=2, note=54, velocity=93, time=0),
#   Message('note_on', channel=2, note=42, velocity=93, time=0)],
#  6.070846841145834: [Message('note_off', channel=1, note=66, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=2, note=54, velocity=0, time=0),
#   Message('note_off', channel=2, note=42, velocity=0, time=0)],
#  6.205545018229167: [Message('note_on', channel=1, note=62, velocity=96, time=0.13469817708333331),
#   Message('note_on', channel=2, note=50, velocity=93, time=0),
#   Message('note_on', channel=2, note=38, velocity=93, time=0)],
#  6.329467341145834: [Message('note_off', channel=1, note=62, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=2, note=50, velocity=0, time=0),
#   Message('note_off', channel=2, note=38, velocity=0, time=0)],
#  6.4641655182291675: [Message('note_on', channel=1, note=66, velocity=96, time=0.13469817708333331),
#   Message('note_on', channel=2, note=54, velocity=93, time=0),
#   Message('note_on', channel=2, note=42, velocity=93, time=0)],
#  6.588087841145835: [Message('note_off', channel=1, note=66, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=2, note=54, velocity=0, time=0),
#   Message('note_off', channel=2, note=42, velocity=0, time=0)],
#  6.722786018229168: [Message('note_on', channel=1, note=69, velocity=96, time=0.13469817708333331),
#   Message('note_on', channel=2, note=57, velocity=93, time=0),
#   Message('note_on', channel=2, note=45, velocity=93, time=0)],
#  6.846708341145835: [Message('note_off', channel=1, note=69, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=2, note=57, velocity=0, time=0),
#   Message('note_off', channel=2, note=45, velocity=0, time=0)],
#  6.981406518229168: [Message('note_on', channel=1, note=66, velocity=96, time=0.13469817708333331),
#   Message('note_on', channel=2, note=54, velocity=93, time=0),
#   Message('note_on', channel=2, note=42, velocity=93, time=0)],
#  7.105328841145835: [Message('note_off', channel=1, note=66, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=2, note=54, velocity=0, time=0),
#   Message('note_off', channel=2, note=42, velocity=0, time=0)],
#  7.240027018229168: [Message('note_on', channel=1, note=62, velocity=96, time=0.13469817708333331),
#   Message('note_on', channel=2, note=50, velocity=93, time=0),
#   Message('note_on', channel=2, note=38, velocity=93, time=0)],
#  7.363949341145835: [Message('note_off', channel=1, note=62, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=2, note=50, velocity=0, time=0),
#   Message('note_off', channel=2, note=38, velocity=0, time=0)],
#  7.498647518229168: [Message('note_on', channel=1, note=66, velocity=96, time=0.13469817708333331),
#   Message('note_on', channel=2, note=54, velocity=93, time=0),
#   Message('note_on', channel=2, note=42, velocity=93, time=0)],
#  7.622569841145835: [Message('note_off', channel=1, note=66, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=2, note=54, velocity=0, time=0),
#   Message('note_off', channel=2, note=42, velocity=0, time=0)],
#  7.757268018229168: [Message('note_on', channel=1, note=69, velocity=96, time=0.13469817708333331),
#   Message('note_on', channel=2, note=57, velocity=93, time=0),
#   Message('note_on', channel=2, note=45, velocity=93, time=0)],
#  7.881190341145835: [Message('note_off', channel=1, note=69, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=2, note=57, velocity=0, time=0),
#   Message('note_off', channel=2, note=45, velocity=0, time=0)],
#  8.015888518229168: [Message('note_on', channel=1, note=66, velocity=96, time=0.13469817708333331),
#   Message('note_on', channel=2, note=54, velocity=93, time=0),
#   Message('note_on', channel=2, note=42, velocity=93, time=0)],
#  8.139810841145835: [Message('note_off', channel=1, note=66, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=2, note=54, velocity=0, time=0),
#   Message('note_off', channel=2, note=42, velocity=0, time=0)],
#  8.274509018229168: [Message('note_on', channel=1, note=62, velocity=96, time=0.13469817708333331),
#   Message('note_on', channel=2, note=50, velocity=93, time=0),
#   Message('note_on', channel=2, note=38, velocity=93, time=0)],
#  8.398431341145834: [Message('note_off', channel=2, note=50, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=2, note=38, velocity=0, time=0)],
#  8.533129518229167: [Message('note_on', channel=2, note=62, velocity=93, time=0.13469817708333331)],
#  8.657051841145833: [Message('note_off', channel=2, note=62, velocity=0, time=0.12392232291666666)],
#  8.7809741640625: [Message('note_off', channel=1, note=62, velocity=0, time=0.12392232291666666)],
#  8.791750018229166: [Message('note_on', channel=2, note=62, velocity=93, time=0.010775854166666666)],
#  8.915672341145832: [Message('note_off', channel=2, note=62, velocity=0, time=0.12392232291666666)],
#  9.050370518229165: [Message('note_on', channel=2, note=62, velocity=93, time=0.13469817708333331)],
#  9.174292841145832: [Message('note_off', channel=2, note=62, velocity=0, time=0.12392232291666666)],
#  9.308991018229165: [Message('note_on', channel=2, note=62, velocity=93, time=0.13469817708333331)],
#  9.43291334114583: [Message('note_off', channel=2, note=62, velocity=0, time=0.12392232291666666)],
#  9.567611518229164: [Message('note_on', channel=2, note=62, velocity=93, time=0.13469817708333331)],
#  9.69153384114583: [Message('note_off', channel=2, note=62, velocity=0, time=0.12392232291666666)],
#  9.826232018229163: [Message('note_on', channel=1, note=83, velocity=69, time=0.13469817708333331),
#   Message('note_on', channel=1, note=86, velocity=69, time=0),
#   Message('note_on', channel=2, note=62, velocity=69, time=0)],
#  9.95015434114583: [Message('note_off', channel=2, note=62, velocity=0, time=0.12392232291666666)],
#  10.084852518229162: [Message('note_off', channel=1, note=83, velocity=0, time=0.13469817708333331),
#   Message('note_off', channel=1, note=86, velocity=0, time=0),
#   Message('note_on', channel=1, note=85, velocity=69, time=0),
#   Message('note_on', channel=1, note=82, velocity=69, time=0),
#   Message('note_on', channel=2, note=62, velocity=69, time=0)],
#  10.208774841145829: [Message('note_off', channel=2, note=62, velocity=0, time=0.12392232291666666)],
#  10.327309236979161: [Message('note_off', channel=1, note=85, velocity=0, time=0.11853439583333333),
#   Message('note_off', channel=1, note=82, velocity=0, time=0)],
#  10.343473018229162: [Message('note_on', channel=1, note=86, velocity=69, time=0.01616378125),
#   Message('note_on', channel=1, note=83, velocity=69, time=0),
#   Message('note_on', channel=2, note=62, velocity=69, time=0)],
#  10.467395341145828: [Message('note_off', channel=1, note=86, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=1, note=83, velocity=0, time=0),
#   Message('note_off', channel=2, note=62, velocity=0, time=0)],
#  10.602093518229161: [Message('note_on', channel=2, note=62, velocity=69, time=0.13469817708333331)],
#  10.726015841145827: [Message('note_off', channel=2, note=62, velocity=0, time=0.12392232291666666)],
#  10.86071401822916: [Message('note_on', channel=1, note=85, velocity=69, time=0.13469817708333331),
#   Message('note_on', channel=1, note=81, velocity=69, time=0),
#   Message('note_on', channel=2, note=62, velocity=69, time=0)],
#  10.984636341145826: [Message('note_off', channel=1, note=85, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=1, note=81, velocity=0, time=0),
#   Message('note_off', channel=2, note=62, velocity=0, time=0)],
#  11.11933451822916: [Message('note_on', channel=2, note=62, velocity=69, time=0.13469817708333331)],
#  11.243256841145826: [Message('note_off', channel=2, note=62, velocity=0, time=0.12392232291666666)],
#  11.377955018229159: [Message('note_on', channel=1, note=83, velocity=69, time=0.13469817708333331),
#   Message('note_on', channel=1, note=79, velocity=69, time=0),
#   Message('note_on', channel=2, note=62, velocity=69, time=0)],
#  11.501877341145825: [Message('note_off', channel=1, note=83, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=1, note=79, velocity=0, time=0),
#   Message('note_off', channel=2, note=62, velocity=0, time=0)],
#  11.636575518229158: [Message('note_on', channel=2, note=62, velocity=69, time=0.13469817708333331)],
#  11.760497841145824: [Message('note_off', channel=2, note=62, velocity=0, time=0.12392232291666666)],
#  11.895196018229157: [Message('note_on', channel=1, note=81, velocity=69, time=0.13469817708333331),
#   Message('note_on', channel=1, note=78, velocity=69, time=0),
#   Message('note_on', channel=2, note=62, velocity=69, time=0)],
#  12.019118341145823: [Message('note_off', channel=1, note=81, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=1, note=78, velocity=0, time=0),
#   Message('note_off', channel=2, note=62, velocity=0, time=0)],
#  12.153816518229156: [Message('note_on', channel=2, note=62, velocity=69, time=0.13469817708333331)],
#  12.277738841145823: [Message('note_off', channel=2, note=62, velocity=0, time=0.12392232291666666)],
#  12.412437018229156: [Message('note_on', channel=1, note=79, velocity=96, time=0.13469817708333331),
#   Message('note_on', channel=1, note=83, velocity=103, time=0),
#   Message('note_on', channel=2, note=50, velocity=93, time=0)],
#  12.466316289062489: [Message('note_off', channel=1, note=83, velocity=0, time=0.05387927083333333)],
#  12.477092143229155: [Message('note_on', channel=1, note=85, velocity=103, time=0.010775854166666666)],
#  12.530971414062488: [Message('note_off', channel=1, note=85, velocity=0, time=0.05387927083333333)],
#  12.536359341145822: [Message('note_off', channel=2, note=50, velocity=0, time=0.005387927083333333)],
#  12.541747268229155: [Message('note_on', channel=1, note=83, velocity=103, time=0.005387927083333333)],
#  12.595626539062488: [Message('note_off', channel=1, note=83, velocity=0, time=0.05387927083333333)],
#  12.606402393229155: [Message('note_on', channel=1, note=85, velocity=103, time=0.010775854166666666)],
#  12.660281664062488: [Message('note_off', channel=1, note=85, velocity=0, time=0.05387927083333333)],
#  12.671057518229155: [Message('note_on', channel=1, note=83, velocity=103, time=0.010775854166666666),
#   Message('note_on', channel=2, note=62, velocity=93, time=0)],
#  12.724936789062488: [Message('note_off', channel=1, note=83, velocity=0, time=0.05387927083333333)],
#  12.735712643229155: [Message('note_on', channel=1, note=85, velocity=103, time=0.010775854166666666)],
#  12.789591914062488: [Message('note_off', channel=1, note=85, velocity=0, time=0.05387927083333333)],
#  12.794979841145821: [Message('note_off', channel=2, note=62, velocity=0, time=0.005387927083333333)],
#  12.800367768229155: [Message('note_on', channel=1, note=81, velocity=103, time=0.005387927083333333)],
#  12.854247039062487: [Message('note_off', channel=1, note=81, velocity=0, time=0.05387927083333333)],
#  12.865022893229154: [Message('note_on', channel=1, note=83, velocity=103, time=0.010775854166666666)],
#  12.918902164062487: [Message('note_off', channel=1, note=79, velocity=0, time=0.05387927083333333),
#   Message('note_off', channel=1, note=83, velocity=0, time=0)],
#  12.929678018229154: [Message('note_on', channel=1, note=78, velocity=96, time=0.010775854166666666),
#   Message('note_on', channel=1, note=81, velocity=96, time=0),
#   Message('note_on', channel=2, note=62, velocity=93, time=0)],
#  13.05360034114582: [Message('note_off', channel=2, note=62, velocity=0, time=0.12392232291666666)],
#  13.188298518229153: [Message('note_on', channel=2, note=62, velocity=93, time=0.13469817708333331)],
#  13.31222084114582: [Message('note_off', channel=2, note=62, velocity=0, time=0.12392232291666666)],
#  13.44153109114582: [Message('note_off', channel=1, note=78, velocity=0, time=0.12931025),
#   Message('note_off', channel=1, note=81, velocity=0, time=0)],
#  13.446919018229153: [Message('note_on', channel=2, note=62, velocity=93, time=0.005387927083333333)],
#  13.570841341145819: [Message('note_off', channel=2, note=62, velocity=0, time=0.12392232291666666)],
#  13.705539518229152: [Message('note_on', channel=2, note=62, velocity=93, time=0.13469817708333331)],
#  13.829461841145818: [Message('note_off', channel=2, note=62, velocity=0, time=0.12392232291666666)],
#  13.964160018229151: [Message('note_on', channel=1, note=83, velocity=69, time=0.13469817708333331),
#   Message('note_on', channel=1, note=74, velocity=69, time=0),
#   Message('note_on', channel=2, note=62, velocity=69, time=0)],
#  14.088082341145817: [Message('note_off', channel=2, note=62, velocity=0, time=0.12392232291666666)],
#  14.22278051822915: [Message('note_off', channel=1, note=83, velocity=0, time=0.13469817708333331),
#   Message('note_off', channel=1, note=74, velocity=0, time=0),
#   Message('note_on', channel=1, note=82, velocity=69, time=0),
#   Message('note_on', channel=1, note=73, velocity=69, time=0),
#   Message('note_on', channel=2, note=62, velocity=69, time=0)],
#  14.346702841145817: [Message('note_off', channel=2, note=62, velocity=0, time=0.12392232291666666)],
#  14.46523723697915: [Message('note_off', channel=1, note=82, velocity=0, time=0.11853439583333333),
#   Message('note_off', channel=1, note=73, velocity=0, time=0)],
#  14.48140101822915: [Message('note_on', channel=1, note=83, velocity=69, time=0.01616378125),
#   Message('note_on', channel=1, note=74, velocity=69, time=0),
#   Message('note_on', channel=2, note=62, velocity=69, time=0)],
#  14.605323341145816: [Message('note_off', channel=1, note=83, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=1, note=74, velocity=0, time=0),
#   Message('note_off', channel=2, note=62, velocity=0, time=0)],
#  14.740021518229149: [Message('note_on', channel=2, note=62, velocity=69, time=0.13469817708333331)],
#  14.863943841145815: [Message('note_off', channel=2, note=62, velocity=0, time=0.12392232291666666)],
#  14.998642018229148: [Message('note_on', channel=1, note=81, velocity=69, time=0.13469817708333331),
#   Message('note_on', channel=1, note=73, velocity=69, time=0),
#   Message('note_on', channel=2, note=62, velocity=69, time=0)],
#  15.122564341145814: [Message('note_off', channel=1, note=81, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=1, note=73, velocity=0, time=0),
#   Message('note_off', channel=2, note=62, velocity=0, time=0)],
#  15.257262518229147: [Message('note_on', channel=2, note=62, velocity=69, time=0.13469817708333331)],
#  15.381184841145814: [Message('note_off', channel=2, note=62, velocity=0, time=0.12392232291666666)],
#  15.515883018229147: [Message('note_on', channel=1, note=79, velocity=69, time=0.13469817708333331),
#   Message('note_on', channel=1, note=71, velocity=69, time=0),
#   Message('note_on', channel=2, note=62, velocity=69, time=0)],
#  15.639805341145813: [Message('note_off', channel=1, note=79, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=1, note=71, velocity=0, time=0),
#   Message('note_off', channel=2, note=62, velocity=0, time=0)],
#  15.774503518229146: [Message('note_on', channel=2, note=62, velocity=69, time=0.13469817708333331)],
#  15.898425841145812: [Message('note_off', channel=2, note=62, velocity=0, time=0.12392232291666666)],
#  16.033124018229145: [Message('note_on', channel=1, note=78, velocity=69, time=0.13469817708333331),
#   Message('note_on', channel=1, note=69, velocity=69, time=0),
#   Message('note_on', channel=2, note=62, velocity=69, time=0)],
#  16.15704634114581: [Message('note_off', channel=1, note=78, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=1, note=69, velocity=0, time=0),
#   Message('note_off', channel=2, note=62, velocity=0, time=0)],
#  16.291744518229144: [Message('note_on', channel=2, note=62, velocity=69, time=0.13469817708333331)],
#  16.41566684114581: [Message('note_off', channel=2, note=62, velocity=0, time=0.12392232291666666)],
#  16.550365018229144: [Message('note_on', channel=1, note=71, velocity=96, time=0.13469817708333331),
#   Message('note_on', channel=1, note=79, velocity=103, time=0),
#   Message('note_on', channel=2, note=50, velocity=93, time=0)],
#  16.60424428906248: [Message('note_off', channel=1, note=79, velocity=0, time=0.05387927083333333)],
#  16.615020143229145: [Message('note_on', channel=1, note=81, velocity=103, time=0.010775854166666666)],
#  16.66889941406248: [Message('note_off', channel=1, note=81, velocity=0, time=0.05387927083333333)],
#  16.674287341145813: [Message('note_off', channel=2, note=50, velocity=0, time=0.005387927083333333)],
#  16.679675268229147: [Message('note_on', channel=1, note=79, velocity=103, time=0.005387927083333333)],
#  16.73355453906248: [Message('note_off', channel=1, note=79, velocity=0, time=0.05387927083333333)],
#  16.74433039322915: [Message('note_on', channel=1, note=81, velocity=103, time=0.010775854166666666)],
#  16.798209664062483: [Message('note_off', channel=1, note=81, velocity=0, time=0.05387927083333333)],
#  16.80898551822915: [Message('note_on', channel=1, note=79, velocity=103, time=0.010775854166666666),
#   Message('note_on', channel=2, note=62, velocity=93, time=0)],
#  16.862864789062485: [Message('note_off', channel=1, note=79, velocity=0, time=0.05387927083333333)],
#  16.87364064322915: [Message('note_on', channel=1, note=81, velocity=103, time=0.010775854166666666)],
#  16.927519914062486: [Message('note_off', channel=1, note=81, velocity=0, time=0.05387927083333333)],
#  16.93290784114582: [Message('note_off', channel=2, note=62, velocity=0, time=0.005387927083333333)],
#  16.938295768229153: [Message('note_on', channel=1, note=78, velocity=103, time=0.005387927083333333)],
#  16.992175039062488: [Message('note_off', channel=1, note=78, velocity=0, time=0.05387927083333333)],
#  17.002950893229155: [Message('note_on', channel=1, note=79, velocity=103, time=0.010775854166666666)],
#  17.05683016406249: [Message('note_off', channel=1, note=71, velocity=0, time=0.05387927083333333),
#   Message('note_off', channel=1, note=79, velocity=0, time=0)],
#  17.067606018229156: [Message('note_on', channel=1, note=69, velocity=96, time=0.010775854166666666),
#   Message('note_on', channel=1, note=78, velocity=96, time=0),
#   Message('note_on', channel=2, note=62, velocity=93, time=0)],
#  17.191528341145823: [Message('note_off', channel=2, note=62, velocity=0, time=0.12392232291666666)],
#  17.326226518229156: [Message('note_on', channel=2, note=62, velocity=93, time=0.13469817708333331)],
#  17.450148841145822: [Message('note_off', channel=2, note=62, velocity=0, time=0.12392232291666666)],
#  17.574071164062488: [Message('note_off', channel=1, note=69, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=1, note=78, velocity=0, time=0)],
#  17.584847018229155: [Message('note_on', channel=1, note=86, velocity=96, time=0.010775854166666666),
#   Message('note_on', channel=2, note=50, velocity=93, time=0)],
#  17.70876934114582: [Message('note_off', channel=2, note=50, velocity=0, time=0.12392232291666666)],
#  17.714157268229155: [Message('note_off', channel=1, note=86, velocity=0, time=0.005387927083333333),
#   Message('note_on', channel=1, note=74, velocity=96, time=0)],
#  17.83807959114582: [Message('note_off', channel=1, note=74, velocity=0, time=0.12392232291666666)],
#  17.843467518229154: [Message('note_on', channel=1, note=73, velocity=96, time=0.005387927083333333),
#   Message('note_on', channel=2, note=54, velocity=93, time=0)],
#  17.96738984114582: [Message('note_off', channel=1, note=73, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=2, note=54, velocity=0, time=0)],
#  17.972777768229154: [Message('note_on', channel=1, note=74, velocity=96, time=0.005387927083333333)],
#  18.08053630989582: [Message('note_off', channel=1, note=74, velocity=0, time=0.10775854166666667)],
#  18.102088018229153: [Message('note_on', channel=1, note=88, velocity=96, time=0.021551708333333332),
#   Message('note_on', channel=2, note=57, velocity=93, time=0)],
#  18.22601034114582: [Message('note_off', channel=2, note=57, velocity=0, time=0.12392232291666666)],
#  18.231398268229153: [Message('note_off', channel=1, note=88, velocity=0, time=0.005387927083333333),
#   Message('note_on', channel=1, note=86, velocity=96, time=0)],
#  18.35532059114582: [Message('note_off', channel=1, note=86, velocity=0, time=0.12392232291666666)],
#  18.360708518229153: [Message('note_on', channel=1, note=85, velocity=96, time=0.005387927083333333),
#   Message('note_on', channel=2, note=54, velocity=93, time=0)],
#  18.48463084114582: [Message('note_off', channel=1, note=85, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=2, note=54, velocity=0, time=0)],
#  18.490018768229152: [Message('note_on', channel=1, note=86, velocity=96, time=0.005387927083333333)],
#  18.597777309895818: [Message('note_off', channel=1, note=86, velocity=0, time=0.10775854166666667)],
#  18.619329018229152: [Message('note_on', channel=1, note=81, velocity=96, time=0.021551708333333332),
#   Message('note_on', channel=2, note=50, velocity=93, time=0)],
#  18.743251341145818: [Message('note_off', channel=2, note=50, velocity=0, time=0.12392232291666666)],
#  18.74863926822915: [Message('note_on', channel=1, note=74, velocity=96, time=0.005387927083333333)],
#  18.872561591145818: [Message('note_off', channel=1, note=74, velocity=0, time=0.12392232291666666)],
#  18.87794951822915: [Message('note_on', channel=1, note=73, velocity=96, time=0.005387927083333333),
#   Message('note_on', channel=2, note=54, velocity=93, time=0)],
#  19.001871841145817: [Message('note_off', channel=1, note=73, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=2, note=54, velocity=0, time=0)],
#  19.00725976822915: [Message('note_on', channel=1, note=74, velocity=96, time=0.005387927083333333)],
#  19.131182091145817: [Message('note_off', channel=1, note=74, velocity=0, time=0.12392232291666666)],
#  19.13657001822915: [Message('note_on', channel=1, note=76, velocity=96, time=0.005387927083333333),
#   Message('note_on', channel=2, note=57, velocity=93, time=0)],
#  19.260492341145817: [Message('note_off', channel=1, note=76, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=2, note=57, velocity=0, time=0)],
#  19.26588026822915: [Message('note_on', channel=1, note=74, velocity=96, time=0.005387927083333333)],
#  19.389802591145816: [Message('note_off', channel=1, note=81, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=1, note=74, velocity=0, time=0)],
#  19.39519051822915: [Message('note_on', channel=1, note=82, velocity=96, time=0.005387927083333333),
#   Message('note_on', channel=1, note=73, velocity=96, time=0),
#   Message('note_on', channel=2, note=54, velocity=93, time=0)],
#  19.519112841145816: [Message('note_off', channel=1, note=73, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=2, note=54, velocity=0, time=0)],
#  19.52450076822915: [Message('note_on', channel=1, note=74, velocity=96, time=0.005387927083333333)],
#  19.648423091145816: [Message('note_off', channel=1, note=82, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=1, note=74, velocity=0, time=0)],
#  19.65381101822915: [Message('note_on', channel=1, note=83, velocity=96, time=0.005387927083333333),
#   Message('note_on', channel=2, note=55, velocity=93, time=0)],
#  19.777733341145815: [Message('note_off', channel=2, note=55, velocity=0, time=0.12392232291666666)],
#  19.78312126822915: [Message('note_off', channel=1, note=83, velocity=0, time=0.005387927083333333),
#   Message('note_on', channel=1, note=74, velocity=96, time=0)],
#  19.907043591145815: [Message('note_off', channel=1, note=74, velocity=0, time=0.12392232291666666)],
#  19.91243151822915: [Message('note_on', channel=1, note=73, velocity=96, time=0.005387927083333333),
#   Message('note_on', channel=2, note=59, velocity=93, time=0)],
#  20.036353841145814: [Message('note_off', channel=1, note=73, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=2, note=59, velocity=0, time=0)],
#  20.041741768229148: [Message('note_on', channel=1, note=74, velocity=96, time=0.005387927083333333)],
#  20.149500309895814: [Message('note_off', channel=1, note=74, velocity=0, time=0.10775854166666667)],
#  20.171052018229148: [Message('note_on', channel=1, note=85, velocity=96, time=0.021551708333333332),
#   Message('note_on', channel=2, note=62, velocity=93, time=0)],
#  20.294974341145814: [Message('note_off', channel=2, note=62, velocity=0, time=0.12392232291666666)],
#  20.300362268229147: [Message('note_off', channel=1, note=85, velocity=0, time=0.005387927083333333),
#   Message('note_on', channel=1, note=83, velocity=96, time=0)],
#  20.424284591145813: [Message('note_off', channel=1, note=83, velocity=0, time=0.12392232291666666)],
#  20.429672518229147: [Message('note_on', channel=1, note=82, velocity=96, time=0.005387927083333333),
#   Message('note_on', channel=2, note=59, velocity=93, time=0)],
#  20.553594841145813: [Message('note_off', channel=1, note=82, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=2, note=59, velocity=0, time=0)],
#  20.558982768229146: [Message('note_on', channel=1, note=83, velocity=96, time=0.005387927083333333)],
#  20.666741309895812: [Message('note_off', channel=1, note=83, velocity=0, time=0.10775854166666667)],
#  20.688293018229146: [Message('note_on', channel=1, note=76, velocity=96, time=0.021551708333333332),
#   Message('note_on', channel=2, note=55, velocity=93, time=0)],
#  20.812215341145812: [Message('note_off', channel=2, note=55, velocity=0, time=0.12392232291666666)],
#  20.817603268229146: [Message('note_off', channel=1, note=76, velocity=0, time=0.005387927083333333),
#   Message('note_on', channel=1, note=74, velocity=96, time=0)],
#  20.941525591145812: [Message('note_off', channel=1, note=74, velocity=0, time=0.12392232291666666)],
#  20.946913518229145: [Message('note_on', channel=1, note=73, velocity=96, time=0.005387927083333333),
#   Message('note_on', channel=2, note=62, velocity=93, time=0)],
#  21.07083584114581: [Message('note_off', channel=1, note=73, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=2, note=62, velocity=0, time=0)],
#  21.076223768229145: [Message('note_on', channel=1, note=74, velocity=96, time=0.005387927083333333)],
#  21.18398230989581: [Message('note_off', channel=1, note=74, velocity=0, time=0.10775854166666667)],
#  21.205534018229145: [Message('note_on', channel=1, note=76, velocity=96, time=0.021551708333333332),
#   Message('note_on', channel=2, note=55, velocity=93, time=0)],
#  21.32945634114581: [Message('note_off', channel=2, note=55, velocity=0, time=0.12392232291666666)],
#  21.334844268229144: [Message('note_off', channel=1, note=76, velocity=0, time=0.005387927083333333),
#   Message('note_on', channel=1, note=74, velocity=96, time=0)],
#  21.45876659114581: [Message('note_off', channel=1, note=74, velocity=0, time=0.12392232291666666)],
#  21.464154518229144: [Message('note_on', channel=1, note=78, velocity=96, time=0.005387927083333333),
#   Message('note_on', channel=2, note=57, velocity=93, time=0)],
#  21.58807684114581: [Message('note_off', channel=1, note=78, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=2, note=57, velocity=0, time=0)],
#  21.593464768229143: [Message('note_on', channel=1, note=74, velocity=96, time=0.005387927083333333)],
#  21.70122330989581: [Message('note_off', channel=1, note=74, velocity=0, time=0.10775854166666667)],
#  21.722775018229143: [Message('note_on', channel=1, note=79, velocity=69, time=0.021551708333333332),
#   Message('note_on', channel=2, note=59, velocity=69, time=0)],
#  21.84669734114581: [Message('note_off', channel=2, note=59, velocity=0, time=0.12392232291666666)],
#  21.852085268229143: [Message('note_off', channel=1, note=79, velocity=0, time=0.005387927083333333),
#   Message('note_on', channel=1, note=74, velocity=69, time=0)],
#  21.97600759114581: [Message('note_off', channel=1, note=74, velocity=0, time=0.12392232291666666)],
#  21.981395518229142: [Message('note_on', channel=1, note=79, velocity=69, time=0.005387927083333333),
#   Message('note_on', channel=1, note=73, velocity=69, time=0)],
#  22.10531784114581: [Message('note_off', channel=1, note=79, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=1, note=73, velocity=0, time=0)],
#  22.110705768229142: [Message('note_on', channel=1, note=74, velocity=69, time=0.005387927083333333)],
#  22.218464309895808: [Message('note_off', channel=1, note=74, velocity=0, time=0.10775854166666667)],
#  22.24001601822914: [Message('note_on', channel=1, note=74, velocity=69, time=0.021551708333333332),
#   Message('note_on', channel=2, note=57, velocity=69, time=0)],
#  22.363938341145808: [Message('note_off', channel=2, note=57, velocity=0, time=0.12392232291666666)],
#  22.36932626822914: [Message('note_off', channel=1, note=74, velocity=0, time=0.005387927083333333),
#   Message('note_on', channel=1, note=73, velocity=69, time=0)],
#  22.493248591145807: [Message('note_off', channel=1, note=73, velocity=0, time=0.12392232291666666)],
#  22.49863651822914: [Message('note_on', channel=1, note=78, velocity=69, time=0.005387927083333333),
#   Message('note_on', channel=1, note=71, velocity=69, time=0)],
#  22.622558841145807: [Message('note_off', channel=1, note=78, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=1, note=71, velocity=0, time=0)],
#  22.62794676822914: [Message('note_on', channel=1, note=73, velocity=69, time=0.005387927083333333)],
#  22.735705309895806: [Message('note_off', channel=1, note=73, velocity=0, time=0.10775854166666667)],
#  22.75725701822914: [Message('note_on', channel=1, note=76, velocity=69, time=0.021551708333333332),
#   Message('note_on', channel=2, note=55, velocity=69, time=0)],
#  22.881179341145806: [Message('note_off', channel=2, note=55, velocity=0, time=0.12392232291666666)],
#  22.88656726822914: [Message('note_off', channel=1, note=76, velocity=0, time=0.005387927083333333),
#   Message('note_on', channel=1, note=71, velocity=69, time=0)],
#  23.010489591145806: [Message('note_off', channel=1, note=71, velocity=0, time=0.12392232291666666)],
#  23.01587751822914: [Message('note_on', channel=1, note=76, velocity=69, time=0.005387927083333333),
#   Message('note_on', channel=1, note=70, velocity=69, time=0)],
#  23.139799841145805: [Message('note_off', channel=1, note=76, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=1, note=70, velocity=0, time=0)],
#  23.14518776822914: [Message('note_on', channel=1, note=71, velocity=69, time=0.005387927083333333)],
#  23.252946309895805: [Message('note_off', channel=1, note=71, velocity=0, time=0.10775854166666667)],
#  23.27449801822914: [Message('note_on', channel=1, note=71, velocity=69, time=0.021551708333333332),
#   Message('note_on', channel=2, note=54, velocity=69, time=0)],
#  23.398420341145805: [Message('note_off', channel=2, note=54, velocity=0, time=0.12392232291666666)],
#  23.403808268229138: [Message('note_off', channel=1, note=71, velocity=0, time=0.005387927083333333),
#   Message('note_on', channel=1, note=69, velocity=69, time=0)],
#  23.527730591145804: [Message('note_off', channel=1, note=69, velocity=0, time=0.12392232291666666)],
#  23.533118518229138: [Message('note_on', channel=1, note=74, velocity=69, time=0.005387927083333333),
#   Message('note_on', channel=1, note=68, velocity=69, time=0)],
#  23.657040841145804: [Message('note_off', channel=1, note=74, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=1, note=68, velocity=0, time=0)],
#  23.662428768229137: [Message('note_on', channel=1, note=69, velocity=69, time=0.005387927083333333)],
#  23.770187309895803: [Message('note_off', channel=1, note=69, velocity=0, time=0.10775854166666667)],
#  23.791739018229137: [Message('note_on', channel=1, note=67, velocity=69, time=0.021551708333333332),
#   Message('note_on', channel=1, note=73, velocity=69, time=0),
#   Message('note_on', channel=2, note=52, velocity=69, time=0)],
#  23.915661341145803: [Message('note_off', channel=1, note=67, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=1, note=73, velocity=0, time=0),
#   Message('note_off', channel=2, note=52, velocity=0, time=0)],
#  24.050359518229136: [Message('note_on', channel=1, note=74, velocity=69, time=0.13469817708333331),
#   Message('note_on', channel=1, note=66, velocity=69, time=0),
#   Message('note_on', channel=2, note=50, velocity=69, time=0)],
#  24.174281841145802: [Message('note_off', channel=1, note=74, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=1, note=66, velocity=0, time=0),
#   Message('note_off', channel=2, note=50, velocity=0, time=0)],
#  24.308980018229136: [Message('note_on', channel=1, note=78, velocity=69, time=0.13469817708333331),
#   Message('note_on', channel=1, note=69, velocity=69, time=0),
#   Message('note_on', channel=2, note=57, velocity=69, time=0)],
#  24.4329023411458: [Message('note_off', channel=2, note=57, velocity=0, time=0.12392232291666666)],
#  24.438290268229135: [Message('note_off', channel=1, note=78, velocity=0, time=0.005387927083333333),
#   Message('note_off', channel=1, note=69, velocity=0, time=0),
#   Message('note_on', channel=1, note=76, velocity=69, time=0),
#   Message('note_on', channel=1, note=67, velocity=69, time=0)],
#  24.5622125911458: [Message('note_off', channel=1, note=76, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=1, note=67, velocity=0, time=0)],
#  24.567600518229135: [Message('note_on', channel=1, note=74, velocity=69, time=0.005387927083333333),
#   Message('note_on', channel=1, note=66, velocity=69, time=0),
#   Message('note_on', channel=2, note=45, velocity=69, time=0)],
#  24.6915228411458: [Message('note_off', channel=1, note=74, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=1, note=66, velocity=0, time=0),
#   Message('note_off', channel=2, note=45, velocity=0, time=0)],
#  24.696910768229134: [Message('note_on', channel=1, note=73, velocity=69, time=0.005387927083333333),
#   Message('note_on', channel=1, note=64, velocity=69, time=0)],
#  24.8046693098958: [Message('note_off', channel=1, note=73, velocity=0, time=0.10775854166666667),
#   Message('note_off', channel=1, note=64, velocity=0, time=0)],
#  24.826221018229134: [Message('note_on', channel=1, note=74, velocity=69, time=0.021551708333333332),
#   Message('note_on', channel=1, note=66, velocity=69, time=0),
#   Message('note_on', channel=2, note=50, velocity=69, time=0)],
#  25.074065664062466: [Message('note_off', channel=1, note=74, velocity=0, time=0.24784464583333332),
#   Message('note_off', channel=1, note=66, velocity=0, time=0)],
#  25.084841518229133: [Message('note_on', channel=1, note=76, velocity=69, time=0.010775854166666666)],
#  25.2087638411458: [Message('note_off', channel=1, note=76, velocity=0, time=0.12392232291666666)],
#  25.214151768229133: [Message('note_on', channel=1, note=78, velocity=72, time=0.005387927083333333)],
#  25.3380740911458: [Message('note_off', channel=1, note=78, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=2, note=50, velocity=0, time=0)],
#  25.343462018229133: [Message('note_on', channel=1, note=79, velocity=77, time=0.005387927083333333)],
#  25.4673843411458: [Message('note_off', channel=1, note=79, velocity=0, time=0.12392232291666666)],
#  25.472772268229132: [Message('note_on', channel=1, note=81, velocity=81, time=0.005387927083333333)],
#  25.5966945911458: [Message('note_off', channel=1, note=81, velocity=0, time=0.12392232291666666)],
#  25.602082518229132: [Message('note_on', channel=1, note=83, velocity=86, time=0.005387927083333333)],
#  25.726004841145798: [Message('note_off', channel=1, note=83, velocity=0, time=0.12392232291666666)],
#  25.73139276822913: [Message('note_on', channel=1, note=85, velocity=92, time=0.005387927083333333)],
#  25.855315091145798: [Message('note_off', channel=1, note=85, velocity=0, time=0.12392232291666666)],
#  25.86070301822913: [Message('note_on', channel=1, note=86, velocity=96, time=0.005387927083333333),
#   Message('note_on', channel=2, note=50, velocity=93, time=0)],
#  25.984625341145797: [Message('note_off', channel=2, note=50, velocity=0, time=0.12392232291666666)],
#  25.99001326822913: [Message('note_off', channel=1, note=86, velocity=0, time=0.005387927083333333),
#   Message('note_on', channel=1, note=74, velocity=96, time=0)],
#  26.113935591145797: [Message('note_off', channel=1, note=74, velocity=0, time=0.12392232291666666)],
#  26.11932351822913: [Message('note_on', channel=1, note=73, velocity=96, time=0.005387927083333333),
#   Message('note_on', channel=2, note=54, velocity=93, time=0)],
#  26.243245841145797: [Message('note_off', channel=1, note=73, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=2, note=54, velocity=0, time=0)],
#  26.24863376822913: [Message('note_on', channel=1, note=74, velocity=96, time=0.005387927083333333)],
#  26.356392309895796: [Message('note_off', channel=1, note=74, velocity=0, time=0.10775854166666667)],
#  26.37794401822913: [Message('note_on', channel=1, note=88, velocity=96, time=0.021551708333333332),
#   Message('note_on', channel=2, note=57, velocity=93, time=0)],
#  26.501866341145796: [Message('note_off', channel=2, note=57, velocity=0, time=0.12392232291666666)],
#  26.50725426822913: [Message('note_off', channel=1, note=88, velocity=0, time=0.005387927083333333),
#   Message('note_on', channel=1, note=86, velocity=96, time=0)],
#  26.631176591145795: [Message('note_off', channel=1, note=86, velocity=0, time=0.12392232291666666)],
#  26.63656451822913: [Message('note_on', channel=1, note=85, velocity=96, time=0.005387927083333333),
#   Message('note_on', channel=2, note=54, velocity=93, time=0)],
#  26.760486841145795: [Message('note_off', channel=1, note=85, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=2, note=54, velocity=0, time=0)],
#  26.76587476822913: [Message('note_on', channel=1, note=86, velocity=96, time=0.005387927083333333)],
#  26.873633309895794: [Message('note_off', channel=1, note=86, velocity=0, time=0.10775854166666667)],
#  26.895185018229128: [Message('note_on', channel=1, note=81, velocity=96, time=0.021551708333333332),
#   Message('note_on', channel=1, note=81, velocity=96, time=0),
#   Message('note_on', channel=2, note=50, velocity=93, time=0)],
#  27.019107341145794: [Message('note_off', channel=1, note=81, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=2, note=50, velocity=0, time=0)],
#  27.024495268229128: [Message('note_on', channel=1, note=74, velocity=96, time=0.005387927083333333)],
#  27.148417591145794: [Message('note_off', channel=1, note=74, velocity=0, time=0.12392232291666666)],
#  27.153805518229127: [Message('note_on', channel=1, note=73, velocity=96, time=0.005387927083333333),
#   Message('note_on', channel=2, note=54, velocity=93, time=0)],
#  27.277727841145794: [Message('note_off', channel=1, note=73, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=2, note=54, velocity=0, time=0)],
#  27.283115768229127: [Message('note_on', channel=1, note=74, velocity=96, time=0.005387927083333333)],
#  27.407038091145793: [Message('note_off', channel=1, note=74, velocity=0, time=0.12392232291666666)],
#  27.412426018229127: [Message('note_on', channel=1, note=76, velocity=96, time=0.005387927083333333),
#   Message('note_on', channel=2, note=57, velocity=93, time=0)],
#  27.536348341145793: [Message('note_off', channel=1, note=76, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=2, note=57, velocity=0, time=0)],
#  27.541736268229126: [Message('note_on', channel=1, note=74, velocity=96, time=0.005387927083333333)],
#  27.66027066406246: [Message('note_off', channel=1, note=81, velocity=0, time=0.11853439583333333)],
#  27.665658591145792: [Message('note_off', channel=1, note=74, velocity=0, time=0.005387927083333333)],
#  27.671046518229126: [Message('note_on', channel=1, note=82, velocity=96, time=0.005387927083333333),
#   Message('note_on', channel=1, note=73, velocity=96, time=0),
#   Message('note_on', channel=2, note=54, velocity=93, time=0)],
#  27.794968841145792: [Message('note_off', channel=1, note=73, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=2, note=54, velocity=0, time=0)],
#  27.800356768229125: [Message('note_on', channel=1, note=74, velocity=96, time=0.005387927083333333)],
#  27.918891164062458: [Message('note_off', channel=1, note=82, velocity=0, time=0.11853439583333333)],
#  27.92427909114579: [Message('note_off', channel=1, note=74, velocity=0, time=0.005387927083333333)],
#  27.929667018229125: [Message('note_on', channel=1, note=83, velocity=96, time=0.005387927083333333),
#   Message('note_on', channel=2, note=55, velocity=93, time=0)],
#  28.05358934114579: [Message('note_off', channel=2, note=55, velocity=0, time=0.12392232291666666)],
#  28.058977268229125: [Message('note_off', channel=1, note=83, velocity=0, time=0.005387927083333333),
#   Message('note_on', channel=1, note=74, velocity=96, time=0)],
#  28.18289959114579: [Message('note_off', channel=1, note=74, velocity=0, time=0.12392232291666666)],
#  28.188287518229124: [Message('note_on', channel=1, note=73, velocity=96, time=0.005387927083333333),
#   Message('note_on', channel=2, note=59, velocity=93, time=0)],
#  28.31220984114579: [Message('note_off', channel=1, note=73, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=2, note=59, velocity=0, time=0)],
#  28.317597768229124: [Message('note_on', channel=1, note=74, velocity=96, time=0.005387927083333333)],
#  28.42535630989579: [Message('note_off', channel=1, note=74, velocity=0, time=0.10775854166666667)],
#  28.446908018229124: [Message('note_on', channel=1, note=85, velocity=96, time=0.021551708333333332),
#   Message('note_on', channel=2, note=62, velocity=93, time=0)],
#  28.57083034114579: [Message('note_off', channel=2, note=62, velocity=0, time=0.12392232291666666)],
#  28.576218268229123: [Message('note_off', channel=1, note=85, velocity=0, time=0.005387927083333333),
#   Message('note_on', channel=1, note=83, velocity=96, time=0)],
#  28.70014059114579: [Message('note_off', channel=1, note=83, velocity=0, time=0.12392232291666666)],
#  28.705528518229123: [Message('note_on', channel=1, note=82, velocity=96, time=0.005387927083333333),
# ...
#   Message('note_on', channel=1, note=78, velocity=96, time=0)],
#  78.35527659114648: [Message('note_off', channel=2, note=57, velocity=0, time=0.01616378125)],
#  78.36066451822981: [Message('note_on', channel=1, note=74, velocity=96, time=0.005387927083333333),
#   Message('note_on', channel=2, note=45, velocity=93, time=0)],
#  78.46303513281315: [Message('note_off', channel=1, note=78, velocity=0, time=0.10237061458333332)],
#  78.48458684114648: [Message('note_off', channel=1, note=74, velocity=0, time=0.021551708333333332),
#   Message('note_off', channel=2, note=45, velocity=0, time=0)],
#  78.48997476822981: [Message('note_on', channel=1, note=76, velocity=96, time=0.005387927083333333),
#   Message('note_on', channel=1, note=73, velocity=96, time=0),
#   Message('note_on', channel=2, note=55, velocity=93, time=0)],
#  78.61389709114648: [Message('note_off', channel=1, note=76, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=1, note=73, velocity=0, time=0),
#   Message('note_off', channel=2, note=55, velocity=0, time=0)],
#  78.61928501822982: [Message('note_on', channel=1, note=74, velocity=96, time=0.005387927083333333),
#   Message('note_on', channel=2, note=54, velocity=93, time=0),
#   Message('note_on', channel=2, note=50, velocity=93, time=0)],
#  79.12575016406315: [Message('note_off', channel=1, note=74, velocity=0, time=0.5064651458333334)],
#  79.13113809114648: [Message('note_off', channel=2, note=54, velocity=0, time=0.005387927083333333),
#   Message('note_off', channel=2, note=50, velocity=0, time=0)],
#  79.13652601822982: [Message('note_on', channel=1, note=66, velocity=69, time=0.005387927083333333),
#   Message('note_on', channel=1, note=57, velocity=69, time=0),
#   Message('note_on', channel=2, note=50, velocity=69, time=0)],
#  79.26044834114649: [Message('note_off', channel=1, note=66, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=1, note=57, velocity=0, time=0),
#   Message('note_off', channel=2, note=50, velocity=0, time=0)],
#  79.39514651822982: [Message('note_on', channel=1, note=66, velocity=69, time=0.13469817708333331),
#   Message('note_on', channel=1, note=57, velocity=69, time=0),
#   Message('note_on', channel=2, note=50, velocity=69, time=0)],
#  79.51906884114649: [Message('note_off', channel=1, note=66, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=1, note=57, velocity=0, time=0),
#   Message('note_off', channel=2, note=50, velocity=0, time=0)],
#  79.65376701822983: [Message('note_on', channel=1, note=66, velocity=69, time=0.13469817708333331),
#   Message('note_on', channel=1, note=57, velocity=69, time=0),
#   Message('note_on', channel=2, note=50, velocity=69, time=0),
#   Message('note_on', channel=2, note=45, velocity=69, time=0)],
#  79.91238751822983: [Message('note_off', channel=1, note=66, velocity=0, time=0.2586205),
#   Message('note_on', channel=1, note=67, velocity=69, time=0),
#   Message('note_off', channel=2, note=50, velocity=0, time=0),
#   Message('note_on', channel=2, note=49, velocity=69, time=0)],
#  80.14406838281317: [Message('note_off', channel=1, note=67, velocity=0, time=0.2316808645833333),
#   Message('note_off', channel=2, note=49, velocity=0, time=0)],
#  80.16562009114651: [Message('note_off', channel=2, note=45, velocity=0, time=0.021551708333333332)],
#  80.17100801822984: [Message('note_on', channel=1, note=64, velocity=69, time=0.005387927083333333),
#   Message('note_on', channel=2, note=52, velocity=69, time=0)],
#  80.42962851822985: [Message('note_off', channel=1, note=64, velocity=0, time=0.2586205),
#   Message('note_on', channel=1, note=61, velocity=69, time=0),
#   Message('note_off', channel=2, note=52, velocity=0, time=0),
#   Message('note_on', channel=2, note=55, velocity=69, time=0)],
#  80.66130938281319: [Message('note_off', channel=1, note=61, velocity=0, time=0.2316808645833333),
#   Message('note_off', channel=2, note=55, velocity=0, time=0)],
#  80.68824901822985: [Message('note_on', channel=1, note=62, velocity=69, time=0.026939635416666666),
#   Message('note_on', channel=2, note=54, velocity=69, time=0),
#   Message('note_on', channel=2, note=50, velocity=69, time=0)],
#  80.94686951822986: [Message('note_off', channel=1, note=57, velocity=0, time=0.2586205),
#   Message('note_off', channel=1, note=62, velocity=0, time=0),
#   Message('note_on', channel=1, note=66, velocity=69, time=0),
#   Message('note_off', channel=2, note=54, velocity=0, time=0),
#   Message('note_on', channel=2, note=57, velocity=69, time=0)],
#  81.18932623697987: [Message('note_off', channel=1, note=66, velocity=0, time=0.24245671875),
#   Message('note_off', channel=2, note=57, velocity=0, time=0)],
#  81.20010209114653: [Message('note_off', channel=2, note=50, velocity=0, time=0.010775854166666666)],
#  81.20549001822987: [Message('note_on', channel=1, note=69, velocity=69, time=0.005387927083333333),
#   Message('note_on', channel=1, note=57, velocity=69, time=0),
#   Message('note_on', channel=2, note=54, velocity=69, time=0)],
#  81.32941234114654: [Message('note_off', channel=1, note=69, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=2, note=54, velocity=0, time=0)],
#  81.46411051822987: [Message('note_on', channel=1, note=66, velocity=69, time=0.13469817708333331),
#   Message('note_on', channel=2, note=50, velocity=69, time=0)],
#  81.58803284114654: [Message('note_off', channel=1, note=66, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=2, note=50, velocity=0, time=0)],
#  81.72273101822988: [Message('note_on', channel=1, note=66, velocity=69, time=0.13469817708333331),
#   Message('note_on', channel=2, note=50, velocity=69, time=0),
#   Message('note_on', channel=2, note=45, velocity=69, time=0)],
#  81.98135151822989: [Message('note_off', channel=1, note=66, velocity=0, time=0.2586205),
#   Message('note_on', channel=1, note=67, velocity=69, time=0),
#   Message('note_off', channel=2, note=50, velocity=0, time=0),
#   Message('note_on', channel=2, note=49, velocity=69, time=0)],
#  82.21303238281322: [Message('note_off', channel=1, note=67, velocity=0, time=0.2316808645833333),
#   Message('note_off', channel=2, note=49, velocity=0, time=0)],
#  82.23458409114656: [Message('note_off', channel=1, note=57, velocity=0, time=0.021551708333333332),
#   Message('note_off', channel=2, note=45, velocity=0, time=0)],
#  82.23997201822989: [Message('note_on', channel=1, note=64, velocity=69, time=0.005387927083333333),
#   Message('note_on', channel=1, note=57, velocity=69, time=0),
#   Message('note_on', channel=2, note=52, velocity=69, time=0)],
#  82.4985925182299: [Message('note_off', channel=1, note=64, velocity=0, time=0.2586205),
#   Message('note_on', channel=1, note=61, velocity=69, time=0),
#   Message('note_off', channel=2, note=52, velocity=0, time=0),
#   Message('note_on', channel=2, note=55, velocity=69, time=0)],
#  82.73027338281324: [Message('note_off', channel=1, note=61, velocity=0, time=0.2316808645833333),
#   Message('note_off', channel=2, note=55, velocity=0, time=0)],
#  82.74643716406324: [Message('note_off', channel=1, note=57, velocity=0, time=0.01616378125)],
#  82.7572130182299: [Message('note_on', channel=1, note=62, velocity=69, time=0.010775854166666666),
#   Message('note_on', channel=1, note=57, velocity=69, time=0),
#   Message('note_on', channel=2, note=54, velocity=69, time=0),
#   Message('note_on', channel=2, note=50, velocity=69, time=0)],
#  83.26906609114657: [Message('note_off', channel=1, note=62, velocity=0, time=0.5118530729166666),
#   Message('note_off', channel=1, note=57, velocity=0, time=0),
#   Message('note_off', channel=2, note=54, velocity=0, time=0),
#   Message('note_off', channel=2, note=50, velocity=0, time=0)],
#  83.2744540182299: [Message('note_on', channel=1, note=78, velocity=96, time=0.005387927083333333),
#   Message('note_on', channel=2, note=62, velocity=93, time=0),
#   Message('note_on', channel=2, note=66, velocity=93, time=0),
#   Message('note_on', channel=2, note=69, velocity=93, time=0)],
#  83.4037642682299: [Message('note_off', channel=1, note=78, velocity=0, time=0.12931025),
#   Message('note_on', channel=1, note=74, velocity=96, time=0)],
#  83.51152280989658: [Message('note_off', channel=1, note=74, velocity=0, time=0.10775854166666667)],
#  83.53307451822991: [Message('note_on', channel=1, note=78, velocity=96, time=0.021551708333333332)],
#  83.64083305989658: [Message('note_on', channel=1, note=74, velocity=96, time=0.10775854166666667)],
#  83.65699684114658: [Message('note_off', channel=1, note=78, velocity=0, time=0.01616378125)],
#  83.76475538281325: [Message('note_off', channel=1, note=74, velocity=0, time=0.10775854166666667)],
#  83.78630709114658: [Message('note_off', channel=2, note=62, velocity=0, time=0.021551708333333332),
#   Message('note_off', channel=2, note=66, velocity=0, time=0),
#   Message('note_off', channel=2, note=69, velocity=0, time=0)],
#  83.79169501822992: [Message('note_on', channel=1, note=81, velocity=96, time=0.005387927083333333),
#   Message('note_on', channel=2, note=62, velocity=93, time=0),
#   Message('note_on', channel=2, note=57, velocity=93, time=0),
#   Message('note_on', channel=2, note=54, velocity=93, time=0)],
#  84.03953966406326: [Message('note_off', channel=1, note=81, velocity=0, time=0.24784464583333332)],
#  84.3035480911466: [Message('note_off', channel=2, note=62, velocity=0, time=0.26400842708333333),
#   Message('note_off', channel=2, note=57, velocity=0, time=0),
#   Message('note_off', channel=2, note=54, velocity=0, time=0)],
#  84.30893601822993: [Message('note_on', channel=1, note=81, velocity=96, time=0.005387927083333333),
#   Message('note_on', channel=2, note=66, velocity=93, time=0),
#   Message('note_on', channel=2, note=62, velocity=93, time=0),
#   Message('note_on', channel=2, note=57, velocity=93, time=0)],
#  84.43824626822993: [Message('note_off', channel=1, note=81, velocity=0, time=0.12931025),
#   Message('note_on', channel=1, note=78, velocity=96, time=0)],
#  84.5460048098966: [Message('note_off', channel=1, note=78, velocity=0, time=0.10775854166666667)],
#  84.56755651822994: [Message('note_on', channel=1, note=81, velocity=96, time=0.021551708333333332)],
#  84.6914788411466: [Message('note_off', channel=1, note=81, velocity=0, time=0.12392232291666666)],
#  84.69686676822994: [Message('note_on', channel=1, note=78, velocity=96, time=0.005387927083333333)],
#  84.82078909114661: [Message('note_off', channel=1, note=78, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=2, note=66, velocity=0, time=0),
#   Message('note_off', channel=2, note=62, velocity=0, time=0),
#   Message('note_off', channel=2, note=57, velocity=0, time=0)],
#  84.82617701822994: [Message('note_on', channel=1, note=86, velocity=96, time=0.005387927083333333),
#   Message('note_on', channel=2, note=62, velocity=93, time=0),
#   Message('note_on', channel=2, note=57, velocity=93, time=0),
#   Message('note_on', channel=2, note=54, velocity=93, time=0),
#   Message('note_on', channel=2, note=50, velocity=93, time=0)],
#  85.3380300911466: [Message('note_off', channel=1, note=86, velocity=0, time=0.5118530729166666),
#   Message('note_off', channel=2, note=62, velocity=0, time=0),
#   Message('note_off', channel=2, note=57, velocity=0, time=0),
#   Message('note_off', channel=2, note=54, velocity=0, time=0),
#   Message('note_off', channel=2, note=50, velocity=0, time=0)],
#  85.34341801822994: [Message('note_on', channel=1, note=62, velocity=96, time=0.005387927083333333),
#   Message('note_on', channel=2, note=50, velocity=93, time=0),
#   Message('note_on', channel=2, note=38, velocity=93, time=0)],
#  85.72057291406327: [Message('note_off', channel=1, note=62, velocity=0, time=0.37715489583333334)],
#  85.7259608411466: [Message('note_off', channel=2, note=50, velocity=0, time=0.005387927083333333),
#   Message('note_off', channel=2, note=38, velocity=0, time=0)],
#  85.73134876822994: [Message('note_on', channel=1, note=62, velocity=108, time=0.005387927083333333),
#   Message('note_on', channel=2, note=50, velocity=104, time=0),
#   Message('note_on', channel=2, note=38, velocity=104, time=0)],
#  85.84988316406327: [Message('note_off', channel=1, note=62, velocity=0, time=0.11853439583333333)],
#  85.8552710911466: [Message('note_off', channel=2, note=50, velocity=0, time=0.005387927083333333),
#   Message('note_off', channel=2, note=38, velocity=0, time=0)],
#  85.86065901822994: [Message('note_on', channel=1, note=62, velocity=96, time=0.005387927083333333),
#   Message('note_on', channel=2, note=50, velocity=93, time=0),
#   Message('note_on', channel=2, note=38, velocity=93, time=0)],
#  86.3725120911466: [Message('note_off', channel=1, note=62, velocity=0, time=0.5118530729166666),
#   Message('note_off', channel=2, note=50, velocity=0, time=0),
#   Message('note_off', channel=2, note=38, velocity=0, time=0)],
#  86.88436516406327: [Message('control_change', channel=0, control=1, value=55, time=0.5118530729166666),
#   Message('note_on', channel=0, note=88, velocity=80, time=0),
#   Message('note_on', channel=1, note=66, velocity=82, time=0),
#   Message('note_on', channel=2, note=62, velocity=81, time=0)],
#  87.0028995598966: [Message('note_off', channel=0, note=88, velocity=0, time=0.11853439583333333)],
#  87.01367541406327: [Message('note_on', channel=0, note=86, velocity=71, time=0.010775854166666666)],
#  87.13759773697994: [Message('note_off', channel=1, note=66, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=2, note=62, velocity=0, time=0)],
#  87.38544238281328: [Message('note_off', channel=0, note=86, velocity=0, time=0.24784464583333332)],
#  87.40160616406328: [Message('note_on', channel=0, note=86, velocity=71, time=0.01616378125),
#   Message('note_on', channel=1, note=71, velocity=82, time=0),
#   Message('note_on', channel=2, note=67, velocity=81, time=0)],
#  87.78953691406328: [Message('note_off', channel=0, note=86, velocity=0, time=0.38793075),
#   Message('note_on', channel=0, note=86, velocity=83, time=0)],
#  87.90807130989661: [Message('note_off', channel=0, note=86, velocity=0, time=0.11853439583333333)],
#  87.91884716406328: [Message('note_on', channel=0, note=86, velocity=78, time=0.010775854166666666),
#   Message('note_off', channel=1, note=71, velocity=0, time=0),
#   Message('note_on', channel=1, note=69, velocity=82, time=0),
#   Message('note_off', channel=2, note=67, velocity=0, time=0),
#   Message('note_on', channel=2, note=66, velocity=81, time=0)],
#  88.42531230989661: [Message('note_off', channel=0, note=86, velocity=0, time=0.5064651458333334)],
#  88.43070023697994: [Message('note_off', channel=1, note=69, velocity=0, time=0.005387927083333333),
#   Message('note_off', channel=2, note=66, velocity=0, time=0)],
#  88.43608816406328: [Message('note_on', channel=0, note=86, velocity=78, time=0.005387927083333333),
#   Message('note_on', channel=1, note=67, velocity=82, time=0),
#   Message('note_on', channel=2, note=64, velocity=81, time=0)],
#  88.93177745572994: [Message('note_off', channel=2, note=64, velocity=0, time=0.49568929166666664)],
#  88.93716538281328: [Message('note_off', channel=1, note=67, velocity=0, time=0.005387927083333333)],
#  88.94255330989661: [Message('note_off', channel=0, note=86, velocity=0, time=0.005387927083333333)],
#  88.95332916406328: [Message('note_on', channel=0, note=86, velocity=78, time=0.010775854166666666),
#   Message('note_on', channel=1, note=66, velocity=82, time=0),
#   Message('note_on', channel=2, note=62, velocity=81, time=0)],
#  89.07725148697995: [Message('note_off', channel=1, note=66, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=2, note=62, velocity=0, time=0)],
#  89.21194966406328: [Message('note_on', channel=1, note=69, velocity=82, time=0.13469817708333331),
#   Message('note_on', channel=1, note=66, velocity=82, time=0),
#   Message('note_on', channel=2, note=62, velocity=81, time=0)],
#  89.33587198697995: [Message('note_off', channel=1, note=69, velocity=0, time=0.12392232291666666),
#   Message('note_off', channel=1, note=66, velocity=0, time=0),
#   Message('note_off', channel=2, note=62, velocity=0, time=0)],
#  ...}

# %%
import pandas as pd
from mido import Message

def make_pitchdf(message_dict):
    """
    Create a DataFrame from a dictionary of MIDI messages, calculating the duration of each note.
    @param:
        - message_dict: dict, keys are elapsed time (in sec) and values are 
                        lists of messages all occurring at that time
            -> dict, {elapsed_time: [msg1, msg2, ...]}
    @return:
        - pd.DataFrame with columns for start time, pitch, MIDI number, velocity, and duration
    """
    note_start_times = {}  # Dictionary to keep track of note start times
    rows = []  # List to store note details including calculated duration

    for elapsed_time, messages in message_dict.items():
        for msg in messages:
            # Check if the message is a note-related message before accessing the note attribute
            if msg.type in ['note_on', 'note_off']:
                key = (msg.channel, msg.note)  # Unique key for each note
                if msg.type == 'note_on' and msg.velocity > 0:
                    # Record the start time of the note
                    velocity = msg.velocity
                    note_start_times[key] = (elapsed_time, velocity)
                elif msg.type == 'note_off' or (msg.type == 'note_on' and msg.velocity == 0):
                    # Calculate duration and prepare the row for DataFrame
                    if key in note_start_times:
                        start_time, velocity = note_start_times[key]
                        duration = elapsed_time - start_time
                        row = [start_time, msg.channel, msg.note, velocity, duration]
                        rows.append(row)
                        del note_start_times[key]  # Remove the note from start times

    # Create DataFrame from the rows
    pitch_df = pd.DataFrame(rows, columns=['start', 'channel', 'pitch', 'velocity', 'duration'])
    return pitch_df

# Example usage
pitch_df = make_pitchdf(message_dict)

# %%
pitch_df
# Out:
#            start  channel  pitch  velocity  duration
# 0       2.067617        1     62        96  0.506465
# 1       2.067617        2     50        93  0.506465
# 2       2.067617        2     38        93  0.506465
# 3       2.584858        1     62        96  0.377155
# 4       2.584858        2     50        93  0.377155
# ...          ...      ...    ...       ...       ...
# 6623  572.474249        2     50        93  0.167151
# 6624  572.474249        2     38        93  0.167151
# 6625  572.648668        1     62        96  0.690407
# 6626  572.648668        2     50        93  0.690407
# 6627  572.648668        2     38        93  0.690407
#
# [6628 rows x 5 columns]

# %%
import time

def play_from_msg_dict(message_dict, program_dict, synthesizer, start_from=0):

    for channel, program_msg in program_dict.items():
        synthesizer.program_select(program_msg.channel, 0, program_msg.program)
        print(f'Set program {program_msg.program} on channel {program_msg.channel}')
    
    # Assuming messages are sorted by time, no need to sort again
    times = list(message_dict.keys())
    
    # Find the index to start from based on the start_from time
    start_index = next((i for i, t in enumerate(times) if t >= start_from), None)
    if start_index is None:
        print("Start time is beyond the last message. Exiting.")
        return
    
    for i in range(start_index, len(times)):
        start_time = times[i]
        messages = message_dict[start_time]
        for msg in messages:
            synthesizer.handle_midi_message(msg)
        if i + 1 < len(times):
            next_start_time = times[i + 1]
            sleep_duration = next_start_time - start_time
            time.sleep(sleep_duration)

# Example usage
# play_from_msg_dict(message_dict, program_dict, synth, start_from=10)
# synth.stop()

# %%
slower_message_dict = {k * 2: v for k, v in message_dict.items()}
play_from_msg_dict(slower_message_dict, program_dict, synth, start_from=0)

# %%
def play_channels(message_dict, program_dict, synthesizer, start_from=0, channels=None):

    for channel, program_msg in program_dict.items():
        synthesizer.program_select(program_msg.channel, 0, program_msg.program)
        print(f'Set program {program_msg.program} on channel {program_msg.channel}')
    
    # Assuming messages are sorted by time, no need to sort again
    times = list(message_dict.keys())
    
    # Find the index to start from based on the start_from time
    start_index = next((i for i, t in enumerate(times) if t >= start_from), None)
    if start_index is None:
        print("Start time is beyond the last message. Exiting.")
        return
    
    for i in range(start_index, len(times)):
        start_time = times[i]
        messages = message_dict[start_time]
        for msg in messages:
            if msg.channel in channels:
                synthesizer.handle_midi_message(msg)
        if i + 1 < len(times):
            next_start_time = times[i + 1]
            sleep_duration = next_start_time - start_time
            time.sleep(sleep_duration)

# Example usage
play_channels(message_dict, program_dict, synth, start_from=30, channels=[1, 2])

# %%
synth.stop()

# %%
import sounddevice as sd
import numpy as np
import time

class AudioRecorder:
    def __init__(self, samplerate=44100, channels=1):
        """Audio recorder class for storing multiple audio recording chunks in a dict"""
        # Config variables
        self.samplerate = samplerate
        self.channels = channels

        # Recording dict to store audio chunks in
        # {tuple(start_time, end_time): np.array(audio_chunk)}
        self.recordings = {} 

        # Initialize recording variables
        self.start_time = None
        self.current_recording = None

    def start_recording(self):
        """Start appending audio chunks to current_recording list"""
        self.start_time = time.time()
        self.current_recording = []
        print("Recording started...")

    def stop_recording(self):
        """Append current_recording to recordings dict and reset variables"""
        if self.start_time is not None:
            end_time = time.time()
            recording_duration = end_time - self.start_time
            recording_key = (self.start_time, end_time)
            self.recordings[recording_key] = np.concatenate(self.current_recording, axis=0)
            self.start_time = None
            self.current_recording = None
            print(f"Recording stopped. Duration: {recording_duration:.2f} seconds")

    def record_callback(self, indata, frames, time, status):
        if self.current_recording is not None:
            self.current_recording.append(indata.copy())

    def start(self):
        """Initialize input stream (not necessarily recording yet)"""
        self.stream = sd.InputStream(samplerate=self.samplerate, channels=self.channels, callback=self.record_callback)
        self.stream.start()

    def stop(self):
        self.stream.stop()
        self.stream.close()

    def play_audio(self, start_time, end_time):
        for key in self.recordings:
            if key[0] <= start_time < key[1] or key[0] < end_time <= key[1] or (start_time <= key[0] and end_time >= key[1]):
                chunk = self.recordings[key]
                sd.play(chunk, samplerate=self.samplerate)
                sd.wait()

    def get_recordings(self):
        return self.recordings

# Usage example
recorder = AudioRecorder()
recorder.start()

# Start recording
recorder.start_recording()
time.sleep(5)  # Record for 5 seconds
recorder.stop_recording()

# Stop the input stream
recorder.stop()

# Play back the recorded audio
recordings = recorder.get_recordings()
for key in recordings:
    print(f"Playing back recording from {key[0]} to {key[1]}")
    recorder.play_audio(key[0], key[1])
# Out:
# Recording started...
# Recording stopped. Duration: 5.01 seconds
# Playing back recording from 1719357695.4525921 to 1719357700.4586828
